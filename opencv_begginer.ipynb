# %%
import cv2

# %%
#reading and showing an image
img=cv2.imread(r"C:\Users\GeetikSharma\OneDrive\Pictures\Screenshots\Screenshot 2025-12-13 173151.png")
cv2.imshow("imgshow",img) # first argument is the name of the gui and second argument is the variable on image source
cv2.waitKey(1000)#if 0 is passed then window will close on pressing any key
cv2.destroyAllWindows()# all the windows will shutdown at once pressing a key
cv2.destroyWindow()# in this number of argument is given and will destroy that window only
# Out:
# -1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
